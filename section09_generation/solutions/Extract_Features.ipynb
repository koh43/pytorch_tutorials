# %%
import numpy as np
import os
from tqdm import tqdm

import torch
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True

from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms.v2 as transforms

from diffusers.models import AutoencoderKL

# %%
use_cuda = torch.cuda.is_available()
gpu_indx  = 0
device = torch.device(gpu_indx if use_cuda else "CPU")
print(torch.cuda.get_device_name(gpu_indx))
# Out:
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
image_size = 256
assert image_size % 8 == 0, "Image size must be divisible by 8 (for the VAE encoder)."

batch_size = 32
dataset_dir = "../data/"
latent_save_dir = "."
os.makedirs(latent_save_dir, exist_ok=True)
print(dataset_dir)
# Out:
# ../data/

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").to(device)

# %%
# Setup data:
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToImage(),
    transforms.ToDtype(torch.float32),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5], inplace=True)
])

dataset = ImageFolder(dataset_dir, transform=transform)
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=8, pin_memory=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 10
#       1 # Setup data:
#       2 transform = transforms.Compose([
#       3     transforms.Resize(image_size),
#       4     transforms.CenterCrop(image_size),
#    (...)      7     transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5], inplace=True)
#       8 ])
# ---> 10 dataset = ImageFolder(dataset_dir, transform=transform)
#      11 data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=8, pin_memory=True)
#
# File ~/miniforge3/envs/pytorch/lib/python3.12/site-packages/torchvision/datasets/folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)    326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
#     332         transform=transform,
#     333         target_transform=target_transform,
#     334         is_valid_file=is_valid_file,
#     335         allow_empty=allow_empty,
#     336     )
#     337     self.imgs = self.samples
#
# File ~/miniforge3/envs/pytorch/lib/python3.12/site-packages/torchvision/datasets/folder.py:149, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     138 def __init__(
#     139     self,
#     140     root: Union[str, Path],
#    (...)    146     allow_empty: bool = False,
#     147 ) -> None:
#     148     super().__init__(root, transform=transform, target_transform=target_transform)
# --> 149     classes, class_to_idx = self.find_classes(self.root)
#     150     samples = self.make_dataset(
#     151         self.root,
#     152         class_to_idx=class_to_idx,
#    (...)    155         allow_empty=allow_empty,
#     156     )
#     158     self.loader = loader
#
# File ~/miniforge3/envs/pytorch/lib/python3.12/site-packages/torchvision/datasets/folder.py:234, in DatasetFolder.find_classes(self, directory)
#     207 def find_classes(self, directory: Union[str, Path]) -> Tuple[List[str], Dict[str, int]]:
#     208     """Find the class folders in a dataset structured as follows::
#     209
#     210         directory/
#    (...)    232         (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     233     """
# --> 234     return find_classes(directory)
#
# File ~/miniforge3/envs/pytorch/lib/python3.12/site-packages/torchvision/datasets/folder.py:43, in find_classes(directory)
#      41 classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42 if not classes:
# ---> 43     raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#      45 class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}
#      46 return classes, class_to_idx
#
# FileNotFoundError: Couldn't find any class folder in ../data/.

# %%
img_index = 0
with torch.no_grad():
    for x, y in tqdm(data_loader, leave=False):
        x = x.to(device)
        y = y.to(device)
        with torch.cuda.amp.autocast():
            # Map input images to latent space + normalize latents:
            latent_features = vae.encode(x).latent_dist.sample().mul_(0.18215)
            latent_features = latent_features.detach().cpu()  # (bs, 4, image_size//8, image_size//8)

        for latent in latent_features.split(1, 0):
            np.save(latent_save_dir + f'/{img_index}.npy', latent.squeeze(0).numpy())
            img_index += 1
